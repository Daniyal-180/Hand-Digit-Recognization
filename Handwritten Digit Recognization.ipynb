# %% [markdown]
# # `Loading Required Packages and Data`

# %%
from tensorflow.keras.datasets import mnist
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from time import time
from tensorflow.keras.utils import to_categorical
import matplotlib.pyplot as plt
# %matplotlib inline
import warnings
import os
warnings.simplefilter(action='ignore', category=FutureWarning)

# %% [markdown]
# # `Data Splitting`

# %%
(x_train, y_train), (x_test, y_test) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 15s 1us/step

# %% [markdown]
# #### `shapes of training and testing data`

# %%
x_train.shape
# Out:
# (60000, 28, 28)

# %%
x_test.shape
# Out:
# (10000, 28, 28)

# %%
y_train.shape
# Out:
# (60000,)

# %%
y_test.shape
# Out:
# (10000,)

# %% [markdown]
# ***
# ***`Conclusion:`*** ***We have 60000 images for training which were 28*28, and we have 10000 images for testing purpose***
# ***

# %% [markdown]
# # `Dataset Display`

# %% [markdown]
# ### `ColorFull Images`

# %%
# number of digit to display
n = 15

# Create a figure to display the image
plt.figure(figsize=(15,4))

# Loop through the first image to n
for i in range(n):
    # Create a subplot within the figure
    ax = plt.subplot(2,n,i+1)
    
    # Display the orignal image
    plt.imshow(x_train[i].reshape(28,28))
    
    # Hide x_axis and y_axis labels and ticks
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
# Show the figure within the image
plt.show()

# Close the figure
plt.close()

# %% [markdown]
# ### `Grascale Images`

# %%
# number of digit to display
n = 15

# Create a figure to display the image
plt.figure(figsize=(15,4))

# Loop through the first image to n
for i in range(n):
    # Create a subplot within the figure
    ax = plt.subplot(2,n,i+1)
    
    # Display the orignal image
    plt.imshow(x_train[i].reshape(28,28))
    
    # Select Colormap to grayscale
    plt.gray()
    
    # Hide x_axis and y_axis labels and ticks
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
# Show the figure within the image
plt.show()

# Close the figure
plt.close()

# %% [markdown]
# ***
# ***`Conclusion:`*** ***We have 7000 images of human written numbers***
# ***

# %% [markdown]
# # `Flattening the Images`

# %%
# Print the shape of orignal data and labels
print(f'Previous x_train shape {x_train.shape} and previous y_train shape {y_train.shape}')
# Out:
# Previous x_train shape (60000, 28, 28) and previous y_train shape (60000,)

# %% [markdown]
# #### `Reshape Training And Testing Data To Flat Format`

# %%
x_train = x_train.reshape(60000,784)
x_test = x_test.reshape(10000,784)

# %% [markdown]
# #### `Print New Shape Of Data`

# %%
# Print the shape of orignal data and labels
print(f'Update x_train shape {x_train.shape} and Updated y_train shape {y_train.shape}')
# Out:
# Update x_train shape (60000, 784) and Updated y_train shape (60000,)

# %% [markdown]
# # `Min-Max Scalling`

# %%
# Convert the data type of the images to float32
x_train = x_train.astype('float32')
x_test = x_test.astype('float32')

# Normalize the pixel values to a range b/w 0 and 1
x_test /= 255
x_train /= 255

# %% [markdown]
# # `Processing The Target Variable`

# %% [markdown]
# ***
# ***`Problem:`*** ***We have images of number b/w 0-9 mean we have 10 target variables to predict. At a time either an image is of number 0 or 1 or 2 or any other. So we need to find a method that we convert these 10 classes into 2 `{0 or 1}`. So we chose `one-hot encoded format`***
# ***

# %%
# Number of Classes
classes = 10

# Convert the label to one-hot encoded format
y_train = to_categorical(y_train,classes)
y_test = to_categorical(y_test,classes)

# Print the Shape of PreProcessd Training Data and Labels
print(f'PreProcessed x_train shape {x_train.shape} and PreProcessed y_train shape {y_train.shape}')

del classes
# Out:
# PreProcessed x_train shape (60000, 784) and PreProcessed y_train shape (60000, 10)

# %% [markdown]
# # `Setting up Hyper Parameters`

# %%
# Define the input size of each data sample
input_size = 784

# Specify the number of data samples to process in each batch
batch_size = 180

# Define The Number Of Neuron In First Hidden Layer
hidden1 = 450

# Define The Number Of Neuron In Second Hidden Layer
hidden2 = 70

# Define The Number Of Neuron In Third Hidden Layer
hidden3 = 20

# Define Total Number Of Classes In Data Set
classes = 10

# Set The Number Of Complete Passes Through The DataSet During Training
epochs = 15

# %% [markdown]
# # `Building The Fully Connected Neural Network(FCN) Model`

# %%
# Create a Sequential model, which allow us to build a neural network layer by layer
model = Sequential()

# Add the first hidden layer with 'hidden1' neurons, using RELu Activation function
model.add(Dense(hidden1, input_dim=input_size, activation='relu'))

# Add the second hidden layer with 'hidden2' neurons, using RELu Activation function
model.add(Dense(hidden2, activation='relu'))

# Add the third hidden layer with 'hidden3' neurons, using RELu Activation function
model.add(Dense(hidden3, activation='relu'))

# Add the output layer with 'classes' neurons, using softmax activation function
model.add(Dense(classes, activation='softmax'))

# Compilation
model.compile(loss='categorical_crossentropy',
             metrics=['accuracy'], optimizer='sgd')

# Display the Summry of Model Acrchitecture, Showing Layers and Parameters Count
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                      │ (None, 450)                 │         353,250 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_5 (Dense)                      │ (None, 70)                  │          31,570 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_6 (Dense)                      │ (None, 20)                  │           1,420 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 10)                  │             210 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 386,450 (1.47 MB)
#  Trainable params: 386,450 (1.47 MB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# # `Training The Model`

# %%
# Record Current Time To Measure Training Time
tic = time()

# Fit The Model On The Training Data
model.fit(x_train, y_train, batch_size=batch_size, epochs=60, verbose=1) # Verbose is for showing training procedure

# Record time after model training
toc = time()
# Out:
# Epoch 1/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9536 - loss: 0.1612
# Epoch 2/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9570 - loss: 0.1521
# Epoch 3/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9579 - loss: 0.1489
# Epoch 4/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9592 - loss: 0.1455
# Epoch 5/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9596 - loss: 0.1410
# Epoch 6/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9617 - loss: 0.1350
# Epoch 7/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9650 - loss: 0.1270
# Epoch 8/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9655 - loss: 0.1259
# Epoch 9/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9662 - loss: 0.1193
# Epoch 10/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9667 - loss: 0.1183
# Epoch 11/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9682 - loss: 0.1121
# Epoch 12/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9699 - loss: 0.1061
# Epoch 13/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9710 - loss: 0.1051
# Epoch 14/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9716 - loss: 0.1009
# Epoch 15/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9721 - loss: 0.0992
# Epoch 16/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9728 - loss: 0.0951
# Epoch 17/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 7ms/step - accuracy: 0.9750 - loss: 0.0913
# Epoch 18/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9749 - loss: 0.0894
# Epoch 19/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9752 - loss: 0.0889
# Epoch 20/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9762 - loss: 0.0865
# Epoch 21/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9764 - loss: 0.0844
# Epoch 22/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9776 - loss: 0.0788
# Epoch 23/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9782 - loss: 0.0793
# Epoch 24/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9799 - loss: 0.0733
# Epoch 25/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9807 - loss: 0.0716
# Epoch 26/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9806 - loss: 0.0721
# Epoch 27/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9812 - loss: 0.0691
# Epoch 28/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9816 - loss: 0.0688
# Epoch 29/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 10ms/step - accuracy: 0.9818 - loss: 0.0660
# Epoch 30/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9821 - loss: 0.0654
# Epoch 31/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9818 - loss: 0.0656
# Epoch 32/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9835 - loss: 0.0605
# Epoch 33/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9838 - loss: 0.0580
# Epoch 34/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9834 - loss: 0.0602
# Epoch 35/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9847 - loss: 0.0576
# Epoch 36/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9851 - loss: 0.0567
# Epoch 37/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9850 - loss: 0.0546
# Epoch 38/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 6s 10ms/step - accuracy: 0.9851 - loss: 0.0531
# Epoch 39/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9868 - loss: 0.0508
# Epoch 40/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9875 - loss: 0.0500
# Epoch 41/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9867 - loss: 0.0495
# Epoch 42/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9879 - loss: 0.0482
# Epoch 43/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9880 - loss: 0.0460
# Epoch 44/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9886 - loss: 0.0463
# Epoch 45/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9893 - loss: 0.0424
# Epoch 46/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9891 - loss: 0.0438
# Epoch 47/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9892 - loss: 0.0415
# Epoch 48/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9901 - loss: 0.0414
# Epoch 49/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9906 - loss: 0.0393
# Epoch 50/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9909 - loss: 0.0380
# Epoch 51/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 9ms/step - accuracy: 0.9912 - loss: 0.0361
# Epoch 52/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9911 - loss: 0.0372
# Epoch 53/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9912 - loss: 0.0357
# Epoch 54/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 9ms/step - accuracy: 0.9919 - loss: 0.0341
# Epoch 55/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9916 - loss: 0.0334
# Epoch 56/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9916 - loss: 0.0353
# Epoch 57/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9925 - loss: 0.0315
# Epoch 58/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9934 - loss: 0.0299
# Epoch 59/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 3s 8ms/step - accuracy: 0.9926 - loss: 0.0307
# Epoch 60/60
# 334/334 ━━━━━━━━━━━━━━━━━━━━ 5s 8ms/step - accuracy: 0.9932 - loss: 0.0301

# %% [markdown]
# ***`Time Taken To Train a Model`***

# %%
print(f'Model Training Took {toc-tic:.2f} seconds')
# Out:
# Model Training Took 180.27 seconds

# %% [markdown]
# # Testing The Model

# %%
from sklearn.metrics import accuracy_score
import numpy as np
import matplotlib.pyplot as plt

# Predict Propabilities for the test size
y_predict_prob = model.predict(x_test,verbose=0)
y_pred = np.where(y_predict_prob > 0.5,1,0)

# Calculate and predict test accuracy using predicted and true label
test_accuracy = accuracy_score(y_pred,y_test)
print(f'Test Accuracy: {test_accuracy*100:.2f}%')
# Out:
# Test Accuracy: 97.43%

# %% [markdown]
# ### `Visculize`

# %%
# Define a mask for selecting a range of indices
mask = range(20, 50)

# Select a range of 20 sample from test set
x_valid = x_test[0:20]
actual_labels = y_test[0:20]

# Predict probabilty for selected validation sammple
y_pred_prob_validation = model.predict(x_valid)
y_valid_pred = np.where(y_pred_prob_validation > 0.5, 1, 0)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step

# %% [markdown]
# ### `Plot`

# %%
n = len(x_valid)

# Create a figure to display the image
plt.figure(figsize=(15,4))

# Loop through the first image to n
for i in range(n):
    # Create a subplot within the figure
    ax = plt.subplot(2,n,i+1)
    
    # Display the orignal image
    plt.imshow(x_valid[i].reshape(28,28))
    
    # Select Colormap to grayscale
    plt.gray()
    
    # Hide x_axis and y_axis labels and ticks
    ax.get_xaxis().set_visible(False)
    ax.get_yaxis().set_visible(False)
    
    # Display Predicted Digit
    predicted_digit = np.argmax(y_valid_pred[i])
    ax = plt.subplot(2, n, i+1+n)
    plt.text(0.5, 0.5, str(predicted_digit), fontsize=14, ha='center', va='center')
    plt.axis('off')
# Show the figure within the image
plt.show()

# Close the figure
plt.close()

# %% [markdown]
# ## `Save the Model`

# %%
# Create a folder named 'model' if it doesn't already exist
os.makedirs('model', exist_ok=True)

# %%
# Save the model in the 'model' folder
model.save('mnist_model.keras')
